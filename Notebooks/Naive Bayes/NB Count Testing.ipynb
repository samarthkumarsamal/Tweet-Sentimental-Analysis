# %% [markdown]
# #### Importing Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import joblib
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
confusion_matrix,classification_report,ConfusionMatrixDisplay,
accuracy_score,precision_score,recall_score,f1_score,
roc_curve,auc
)

# %% [markdown]
# #### Loading the Testing Sets

# %%
df = pd.read_csv("../../Dataset/Testing-Dataset.csv",keep_default_na=False)
df.head()
# Out:
#                                                 Text  Target
# 0  yes black red fav color really wanted color de...       0
# 1  buy open house weekend ampm best value bedroom...       1
# 2          fran greet air thats okay hahahaha thanks       1
# 3  omg thats awesome goood luck meet caaute calga...       1
# 4                               hahahhaha good point       1

# %% [markdown]
# #### Loading the Model

# %%
model = joblib.load("../../Models/nb-count.joblib")
model
# Out:
# Pipeline(steps=[('count',
#                  CountVectorizer(max_df=0.9, max_features=200000, min_df=3,
#                                  ngram_range=(1, 2))),
#                 ('nb', MultinomialNB(alpha=0.5))])

# %% [markdown]
# #### Splitting the Dataset

# %%
x_test = df['Text']
y_test = df['Target']

# %% [markdown]
# #### Predicting the Values

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1], shape=(320000,))

# %%
y_proba = model.predict_proba(x_test)[:,1]
y_proba
# Out:
# array([9.99979861e-01, 8.52950183e-01, 9.91387371e-01, ...,
#        5.66723923e-01, 1.32180047e-05, 8.64382262e-01], shape=(320000,))

# %%
results_df = pd.DataFrame({
    "y_test": y_test,
    "y_pred": y_pred
})

results_df.sample(10)
# Out:
#         y_test  y_pred
# 10931        1       1
# 141260       1       1
# 172384       1       1
# 2594         0       0
# 61313        1       1
# 156869       1       1
# 200062       1       1
# 205271       1       1
# 16224        1       1
# 232092       1       1

# %% [markdown]
# #### Classification Metrics

# %%
print("Classification Report :")
print(classification_report(y_test,y_pred))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78    160000
#            1       0.78      0.77      0.78    160000
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000

# %%
print("Classification Metrics :")
metrics_df = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1 Score"],
    "Score": [
        accuracy_score(y_test, y_pred),
        precision_score(y_test, y_pred),
        recall_score(y_test, y_pred),
        f1_score(y_test, y_pred)
    ]
})

metrics_df
# Out:
# Classification Metrics :
#       Metric     Score
# 0   Accuracy  0.775953
# 1  Precision  0.776803
# 2     Recall  0.774419
# 3   F1 Score  0.775609

# %% [markdown]
# #### Computing and Plotting the Confusion Matrix

# %%
cm = confusion_matrix(y_test,y_pred)
print("Confusion Matrix :")
print(cm)
# Out:
# Confusion Matrix :
# [[124398  35602]
#  [ 36093 123907]]

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### Plotting the ROC-AUC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC-AUC Curve")
plt.legend(loc="lower right")
plt.show()
